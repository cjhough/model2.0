# %%
# !pwd
# Out:
# /Users/carly/CODE/model2.0/storeresults

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pwd
# Out:
# /Users/carly/CODE/model2.0/storeresults

# %%
pathname = str('/Users/carly/CODE/model2.0/initials/')
modelpath = str('/Users/carly/CODE/model2.0/')
#savepath = str('/Users/carly/Desktop/')

# %%
def readchi(name):
    chiread = pd.read_pickle(name+'CHISQ.pkl')
    return chiread
def readtheta(name):
    thetaread = pd.read_pickle(name+'THETA.pkl')
    return thetaread
def readsum(name):
    sumread  = pd.read_pickle(name+'SUM.pkl')
    return sumread

# %%
# !ls *.pkl
# Out:
# IP2_200_200CHISQ.pkl           artifice1branch2_100THETA.pkl
# IP2_200_200SUM.pkl             artifice2_200_200CHISQ.pkl
# IP2_200_200THETA.pkl           artifice2_200_200SUM.pkl
# artifice1_200_200CHISQ.pkl     artifice2_200_200THETA.pkl
# artifice1_200_200SUM.pkl       artifice_3_200_200CHISQ.pkl
# artifice1_200_200THETA.pkl     artifice_3_200_200SUM.pkl
# artifice1branch100100CHISQ.pkl artifice_3_200_200THETA.pkl
# artifice1branch100100SUM.pkl   beethoven1_100CHISQ.pkl
# artifice1branch100100THETA.pkl beethoven1_100SUM.pkl
# artifice1branch2_100CHISQ.pkl  beethoven1_100THETA.pkl
# artifice1branch2_100SUM.pkl

# %%
#p1 = str('artifice1_200_200')

# %%
mcsum = readsum(p1)
mctheta = readtheta(p1)
mcchi = readchi(p1)

# %%
fig = plt.Figure()

mcsum.plot.line(title='')

fig.set_size_inches(10,8)
#fig.tight_layout()
fig.get_figure()

#fig.savefig('/Users/carly/Desktop/artifice1_MCMC')

# %%
mcsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 100
# Data columns (total 5 columns):
# FIRST_EPOCH_PROB_U1    101 non-null float64
# MEAN_U1                101 non-null float64
# MEAN_U2                101 non-null float64
# SD_U1                  101 non-null float64
# SD_U2                  101 non-null float64
# dtypes: float64(5)
# memory usage: 4.7 KB

# %%
allchi = mcsum.sum(axis=1)
allchi.idxmin()
# Out:
# 95

# %%
def kc(dic):
    s1 = dic
    for key, value in s1.items():
        # do something with value
        s1[key] = value
    return s1

# %%
#thetakc = pd.DataFrame.from_records(dfc3theta['KC'])

# %%
steps = len(mcsum)
x0 = np.arange(0,steps)

# %%
theta = mctheta
theta
# Out:
#         alpha      beta     gamma        kb        kc        ks        mu  \
# 0    0.000067  0.943724  1.347079  0.109861  0.003166  0.178345  1.067869
# 1    0.000067  0.943724  1.347079  0.109861  0.003166  0.178345  1.067869
# 2    0.000067  0.943724  1.347079  0.109861  0.003166  0.178345  1.067869
# 3    0.000067  0.943724  1.347079  0.109861  0.003166  0.178345  1.067869
# 4    0.000069  0.897961  1.293967  0.112036  0.003219  0.167452  1.042221
# 5    0.000069  0.897961  1.293967  0.112036  0.003219  0.167452  1.042221
# 6    0.000069  0.897961  1.293967  0.112036  0.003219  0.167452  1.042221
# 7    0.000069  0.897961  1.293967  0.112036  0.003219  0.167452  1.042221
# 8    0.000069  0.897961  1.293967  0.112036  0.003219  0.167452  1.042221
# 9    0.000069  0.897961  1.293967  0.112036  0.003219  0.167452  1.042221
# 10   0.000069  0.897961  1.293967  0.112036  0.003219  0.167452  1.042221
ax[0,0].plot(x0,theta['beta'],color='blue',label='BETA')
ax[0,1].plot(x0,theta['gamma'],color='green',label='GAMMA')
ax[0,2].plot(x0,theta['sigma'],color='purple',label='SIGMA')
ax[1,0].plot(x0,theta['alpha'],color='yellow',label='ALPHA')
ax[1,1].plot(x0,theta['mu'],color='black',label='MU')
ax[1,2].plot(x0,theta['kb'],color='pink',label='BASELINE INPUT (KB)')
ax[2,0].plot(x0,theta['tau_a'],color='orange',label='TAU_A')
ax[2,1].plot(x0,theta['tau_u'],color='brown',label='TAU_U')
ax[3,0].plot(x0,theta['ks'],color='red',label='not from contrast')
ax[3,1].plot(x0,theta['kc'],color='blue',label='contrast')


ax[0,0].set_title('BETA')
ax[0,1].set_title('GAMMA')
ax[0,2].set_title('SIGMA (noise)')
ax[1,0].set_title('ALPHA')
ax[1,1].set_title('MU')
ax[1,2].set_title('BASELINE INPUT (KB)')
ax[2,0].set_title('TAU_A')
ax[2,1].set_title('TAU_U')
ax[3,0].set_title('Not Contrast Stimulus')
ax[3,1].set_title('Contrast Stimulus')

fig.tight_layout()
fig.get_figure()
fig.set_size_inches(10,10)
#fig.savefig(savepath+'', dpi=100)

# %%
chicol = ['CHI: First Epoch Probability',
          'CHI: U1 Mean Dominance Time',
          'CHI: U2 Mean Dominance Time',
          'CHI: U1 std for CV=0.6',
          'CHI: U2 std for CV=0.6'
         ]

# %%
best = allchi.idxmin()

# %%
dfbest = pd.DataFrame(mcchi[best])
chiallsave = dfbest.T
chiallsave.columns = chicol
#chiallsave.index.name = 1
chiallsave
# Out:
#     CHI: First Epoch Probability  CHI: U1 Mean Dominance Time  \
# 0                       0.020002                     0.156234
# 20                     21.645022                     0.042481
# 40                      0.000000                     0.263806
# 60                      0.000000                     0.487275
# 80                      0.000000                     0.276282
#
#     CHI: U2 Mean Dominance Time  CHI: U1 std for CV=0.6  \
# 0                      0.024529                2.826902
# 20                     0.222060                2.827336
# 40                     0.820587                2.732755
# 60                     0.965756                4.818485
# 80                     1.040979                6.515600
#
#     CHI: U2 std for CV=0.6
# 0                 2.239512
# 20                3.520529
# 40                3.849573
# 60                5.826465
# 80                8.606517

# %%
thetasave = mctheta.iloc[best]
thetasave
# Out:
# alpha       0.000055
# beta        0.953199
# gamma       1.335695
# kb          0.126907
# kc          0.004242
# ks          0.180886
# mu          0.987007
# sigma       0.027238
# tau_a    2414.616338
# tau_u      12.407310
# Name: 95, dtype: float64

# %%
#thetasave['alpha']=0.0001

# %%
#thetasave.to_pickle(pathname+'bach.pkl')
#thetasave.to_pickle(modelpath+'bach.pkl')

# %%
colsum = dfbest.sum(axis=1)
colsum['CHI SUM'] = colsum.sum()
colsum
# Out:
# FIRST_EPOCH_PROB_U1    21.665024
# MEAN_U1                 1.226078
# MEAN_U2                 3.073912
# SD_U1                  19.721079
# SD_U2                  24.042596
# CHI SUM                69.728688
# dtype: float64

# %%
x = np.linspace(0, 2 * np.pi, 400)
z = np.linspace(0, 4 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, ax = plt.subplots(4,2)
#figsize=(10,14)

ax[0,0].plot(z,y)
ax[0,1].plot(x,y)

fig.get_figure()
fig.tight_layout()
fig.set_size_inches(8,8)
