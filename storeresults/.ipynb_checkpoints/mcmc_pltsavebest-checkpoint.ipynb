# %%
# !pwd
# Out:
# /Users/houghtoncj/Documents/GitHub/model2.0/storeresults

# %%
# !ls *.pkl
# Out:
# CHISQpmc1.pkl        IP2_200_200THETA.pkl pm200_100THETA.pkl
# CHISQpmc10.pkl       IP2_200_50CHISQ.pkl  pm200_150CHISQ.pkl
# IP2_200_100CHISQ.pkl IP2_200_50SUM.pkl    pm200_150SUM.pkl
# IP2_200_100SUM.pkl   IP2_200_50THETA.pkl  pm200_150THETA.pkl
# IP2_200_100THETA.pkl SUMpmc1.pkl          pm200_200CHISQ.pkl
# IP2_200_150CHISQ.pkl SUMpmc10.pkl         pm200_200SUM.pkl
# IP2_200_150SUM.pkl   THETApmc1.pkl        pm200_200THETA.pkl
# IP2_200_150THETA.pkl THETApmc10.pkl       pm200_50CHISQ.pkl
# IP2_200_200CHISQ.pkl pm200_100CHISQ.pkl   pm200_50SUM.pkl
# IP2_200_200SUM.pkl   pm200_100SUM.pkl     pm200_50THETA.pkl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pathname = str('/Users/houghtoncj/Documents/GitHub/model2.0/storeresults/')
modelpath = str('/Users/houghtoncj/Documents/GitHub/model2.0/')
#savepath = str('/Users/carly/Desktop/')

# %%
def readchi(name):
    chiread = pd.read_pickle(name+'CHISQ.pkl')
    return chiread
def readtheta(name):
    thetaread = pd.read_pickle(name+'THETA.pkl')
    return thetaread
def readsum(name):
    sumread  = pd.read_pickle(name+'SUM.pkl')
    return sumread

# %%
mc1 = str('IP2_200_200')

# %%
mc1sum = readsum(mc1)
mc1theta = readtheta(mc1)
mc1chi = readchi(mc1)

# %%
fig, axs = plt.subplots(2)

mc1sum.plot.line(ax = axs[0])

fig.set_size_inches(8,8)
fig.tight_layout()
fig.get_figure()

#fig.savefig(savepath+'',dpi=100)

# %%
mc1sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 200
# Data columns (total 5 columns):
# FIRST_EPOCH_PROB_U1    201 non-null float64
# MEAN_U1                201 non-null float64
# MEAN_U2                201 non-null float64
# SD_U1                  201 non-null float64
# SD_U2                  201 non-null float64
# dtypes: float64(5)
# memory usage: 9.4 KB

# %%
allchi = mc1sum.sum(axis=1)
allchi.idxmin()
# Out:
# 157

# %%
def kc(dic):
    s1 = dic
    for key, value in s1.items():
        # do something with value
        s1[key] = value
    return s1

# %%
#thetakc = pd.DataFrame.from_records(dfc3theta['KC'])

# %%
steps = len(mc1sum)
x0 = np.arange(0,steps)

# %%
theta = mc1theta
theta
# Out:
#         alpha      beta     gamma        kb        kc        ks        mu  \
# 0    0.000100  1.127209  1.777396  0.100947  0.002921  0.228017  1.122287
# 1    0.000100  1.127209  1.777396  0.100947  0.002921  0.228017  1.122287
# 2    0.000100  1.127209  1.777396  0.100947  0.002921  0.228017  1.122287
.000080  1.121462  1.670622  0.124143  0.002489  0.195865  1.273642
#
#         sigma        tau_a      tau_u
# 0    0.045653  1500.853819   8.940977
# 1    0.045653  1500.853819   8.940977
# 2    0.045653  1500.853819   8.940977
# 3    0.045233  1470.928471   9.021320
# 4    0.045233  1470.928471   9.021320
# 5    0.045233  1470.928471   9.021320
# 6    0.042327  1598.983055   9.219991
# 7    0.042327  1598.983055   9.219991
# 8    0.042327  1598.983055   9.219991
# 9    0.042327  1598.983055   9.219991
# 10   0.042327  1598.983055   9.219991
# 11   0.042327  1598.983055   9.219991
# 12   0.042327  1598.983055   9.219991
# 13   0.042327  1598.983055   9.219991
# 14   0.042327  1598.983055   9.219991
# 15   0.042327  1598.983055   9.219991
# 16   0.042327  1598.983055   9.219991
# 17   0.042327  1598.983055   9.219991
# 18   0.042327  1598.983055   9.219991
# 19   0.042327  1598.983055   9.219991
# 20   0.042327  1598.983055   9.219991
# 21   0.042327  1598.983055   9.219991
# 22   0.042327  1598.983055   9.219991
# 23   0.046267  1613.216907   9.291861
# 24   0.046267  1613.216907   9.291861
# 25   0.046267  1613.216907   9.291861
# 26   0.046267  1613.216907   9.291861
# 27   0.046267  1613.216907   9.291861
# 28   0.046267  1613.216907   9.291861
# 29   0.046267  1613.216907   9.291861
# ..        ...          ...        ...
# 171  0.040128  1849.408587  10.048476
# 172  0.040128  1849.408587  10.048476
# 173  0.040128  1849.408587  10.048476
# 174  0.040128  1849.408587  10.048476
# 175  0.040128  1849.408587  10.048476
# 176  0.040128  1849.408587  10.048476
# 177  0.040128  1849.408587  10.048476
# 178  0.040128  1849.408587  10.048476
# 179  0.040128  1849.408587  10.048476
# 180  0.040128  1849.408587  10.048476
# 181  0.040128  1849.408587  10.048476
# 182  0.040128  1849.408587  10.048476
# 183  0.040128  1849.408587  10.048476
# 184  0.040128  1849.408587  10.048476
# 185  0.040128  1849.408587  10.048476
# 186  0.040128  1849.408587  10.048476
# 187  0.040128  1849.408587  10.048476
# 188  0.040128  1849.408587  10.048476
# 189  0.040128  1849.408587  10.048476
# 190  0.040128  1849.408587  10.048476
# 191  0.040128  1849.408587  10.048476
# 192  0.040128  1849.408587  10.048476
# 193  0.040128  1849.408587  10.048476
# 194  0.040128  1849.408587  10.048476
# 195  0.040128  1849.408587  10.048476
# 196  0.040128  1849.408587  10.048476
# 197  0.040128  1849.408587  10.048476
# 198  0.040128  1849.408587  10.048476
# 199  0.040128  1849.408587  10.048476
# 200  0.040128  1849.408587  10.048476
#
# [201 rows x 10 columns]

# %%
theta = mc1theta
fig,ax = plt.subplots(4,3)

ax[0,0].plot(x0,theta['beta'],color='blue',label='BETA')
ax[0,1].plot(x0,theta['gamma'],color='green',label='GAMMA')
ax[0,2].plot(x0,theta['sigma'],color='purple',label='SIGMA')
ax[1,0].plot(x0,theta['alpha'],color='yellow',label='ALPHA')
ax[1,1].plot(x0,theta['mu'],color='black',label='MU')
ax[1,2].plot(x0,theta['kb'],color='pink',label='BASELINE INPUT (KB)')
ax[2,0].plot(x0,theta['tau_a'],color='orange',label='TAU_A')
ax[2,1].plot(x0,theta['tau_u'],color='brown',label='TAU_U')
ax[3,0].plot(x0,theta['ks'],color='red',label='not from contrast')
ax[3,1].plot(x0,theta['kc'],color='blue',label='contrast')


ax[0,0].set_title('BETA')
ax[0,1].set_title('GAMMA')
ax[0,2].set_title('SIGMA (noise)')
ax[1,0].set_title('ALPHA')
ax[1,1].set_title('MU')
ax[1,2].set_title('BASELINE INPUT (KB)')
ax[2,0].set_title('TAU_A')
ax[2,1].set_title('TAU_U')
ax[3,0].set_title('Not Contrast Stimulus')
ax[3,1].set_title('Contrast Stimulus')

fig.tight_layout()
fig.get_figure()
fig.set_size_inches(10,10)
#fig.savefig(savepath+'', dpi=100)

# %%
chicol = ['CHI: First Epoch Probability',
          'CHI: U1 Mean Dominance Time',
          'CHI: U2 Mean Dominance Time',
          'CHI: U1 std for CV=0.6',
          'CHI: U2 std for CV=0.6'
         ]

# %%
best = allchi.idxmin()

# %%
dfbest = pd.DataFrame(mc1chi[best])
chiallsave = dfbest.T
chiallsave.columns = chicol
#chiallsave.index.name = 1
chiallsave
# Out:
#     CHI: First Epoch Probability  CHI: U1 Mean Dominance Time  \
# 0                       0.000000                     1.157204
# 20                     74.955437                     1.013517
# 40                     72.321429                     2.157158
# 60                     33.918129                     3.829588
# 80                     11.640212                     5.563989
#
#     CHI: U2 Mean Dominance Time  CHI: U1 std for CV=0.6  \
# 0                      0.686383                4.378754
# 20                     0.754685                5.629079
# 40                     1.230443                5.806879
# 60                     1.477382                8.020020
# 80                     1.964120                8.999730
#
#     CHI: U2 std for CV=0.6
# 0                 3.658291
# 20                5.254778
# 40                4.667195
# 60                5.442303
# 80                5.328359

# %%
thetasave = mc1theta.iloc[best]
thetasave
# Out:
# alpha       0.000080
# beta        1.121462
# gamma       1.670622
# kb          0.124143
# kc          0.002489
# ks          0.195865
# mu          1.273642
# sigma       0.040128
# tau_a    1849.408587
# tau_u      10.048476
# Name: 157, dtype: float64

# %%
#thetasave['alpha']=0.0001

# %%
#thetasave.to_pickle(pathname+'IP2.pkl')
#thetasave.to_pickle(modelpath+'artifice.pkl')

# %%
colsum = dfbest.sum(axis=1)
colsum['CHI SUM'] = colsum.sum()
colsum
# Out:
# FIRST_EPOCH_PROB_U1    192.835206
# MEAN_U1                 13.721457
# MEAN_U2                  6.113013
# SD_U1                   32.834462
# SD_U2                   24.350926
# CHI SUM                269.855063
# dtype: float64

# %%
x = np.linspace(0, 2 * np.pi, 400)
z = np.linspace(0, 4 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, ax = plt.subplots(4,2)
#figsize=(10,14)

ax[0,0].plot(z,y)
ax[0,1].plot(x,y)

fig.get_figure()
fig.tight_layout()
fig.set_size_inches(8,8)
