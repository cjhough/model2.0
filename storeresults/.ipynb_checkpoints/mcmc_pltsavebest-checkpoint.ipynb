# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pwd
# Out:
# /Users/carly/CODE/model2.0/storeresults

# %%
pathname = str('/Users/carly/CODE/model2.0/initials/')
modelpath = str('/Users/carly/CODE/model2.0/')
datapath = str('/Users/carly/CODE/model2.0/')

# %%
def readchi(name):
    chiread = pd.read_pickle(name+'CHISQ.pkl')
    return chiread
def readtheta(name):
    thetaread = pd.read_pickle(name+'THETA.pkl')
    return thetaread
def readsum(name):
    sumread  = pd.read_pickle(name+'SUM.pkl')
    return sumread

# %%
# !ls /Users/carly/CODE/model2.0/*.pkl
# Out:
# /Users/carly/CODE/model2.0/bach.pkl
# /Users/carly/CODE/model2.0/bach140.pkl
# /Users/carly/CODE/model2.0/barber.pkl
# /Users/carly/CODE/model2.0/beethoven.pkl
# /Users/carly/CODE/model2.0/beethoven6.pkl
# /Users/carly/CODE/model2.0/beethoven7.pkl
# /Users/carly/CODE/model2.0/beethoven8.pkl
# /Users/carly/CODE/model2.0/bizet.pkl
# /Users/carly/CODE/model2.0/brahms.pkl
# /Users/carly/CODE/model2.0/bruch.pkl
# /Users/carly/CODE/model2.0/bruch200.pkl
# /Users/carly/CODE/model2.0/cepbach.pkl
# /Users/carly/CODE/model2.0/cepbach95.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM100CHISQ.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM100SUM.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM100THETA.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM20CHISQ.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM20SUM.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM20THETA.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM40CHISQ.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM40SUM.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM40THETA.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM60CHISQ.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM60SUM.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM60THETA.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM80CHISQ.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM80SUM.pkl
# /Users/carly/CODE/model2.0/cepbach_DECREASESTIM80THETA.pkl
# /Users/carly/CODE/model2.0/chopin.pkl
# /Users/carly/CODE/model2.0/chopin2.pkl
# /Users/carly/CODE/model2.0/copland.pkl
# /Users/carly/CODE/model2.0/couperin.pkl
# /Users/carly/CODE/model2.0/couperin2.pkl
# /Users/carly/CODE/model2.0/faure.pkl
# /Users/carly/CODE/model2.0/strauss.pkl

# %%
p1 = datapath+str('cepbach_DECREASESTIM100')

# %%
#bach/cepbach
#barber/copland
#beethoven3/beethoven6
#beethoven4/beethoven8
#beethoven5/beethoven7
#bizet/strauss
#brahms/faure
#bruch
#beethoven2/chopin/
#beethoven9/couperin

# %%
mcsum = readsum(p1)
mctheta = readtheta(p1)
mcchi = readchi(p1)

# %%
fig = plt.Figure()

mcsum.plot.line(title='cepbach_DECREASESTIM100')

fig.set_size_inches(10,8)
#fig.tight_layout()
fig.get_figure()

#fig.savefig('/Users/carly/Desktop/artifice1_MCMC')

# %%
mcsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 100
# Data columns (total 5 columns):
# FIRST_EPOCH_PROB_U1    101 non-null float64
# MEAN_U1                101 non-null float64
# MEAN_U2                101 non-null float64
# SD_U1                  101 non-null float64
# SD_U2                  101 non-null float64
# dtypes: float64(5)
# memory usage: 4.7 KB

# %%
allchi = mcsum.sum(axis=1)
allchi.idxmin()
# Out:
# 75

# %%
def kc(dic):
    s1 = dic
    for key, value in s1.items():
        # do something with value
        s1[key] = value
    return s1

# %%
#thetakc = pd.DataFrame.from_records(dfc3theta['KC'])

# %%
steps = len(mcsum)
x0 = np.arange(0,steps)

# %%
theta = mctheta
theta
# Out:
#         alpha      beta     gamma        kb        kc        ks        mu  \
# 0    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 1    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 2    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 3    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 4    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 5    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 6    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 7    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 8    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 9    0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 10   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 11   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 12   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 13   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 14   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 15   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 16   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 17   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 18   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 19   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 20   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 21   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 22   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 23   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 24   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 25   0.000044  0.840795  1.104236  0.118590  0.004667  0.170864  0.898149
# 26   0.000046  0.816760  1.028626  0.110022  0.004921  0.171552  0.959347
# 27   0.000046  0.816760  1.028626  0.110022  0.004921  0.171552  0.959347
# 28   0.000046  0.816760  1.028626  0.110022  0.004921  0.171552  0.959347
# 29   0.000046  0.816760  1.028626  0.110022  0.004921  0.171552  0.959347
# ..        ...       ...       ...       ...       ...       ...       ...
# 71   0.000041  0.834456  1.103663  0.101424  0.004799  0.180241  1.004191
# 72   0.000041  0.834456  1.103663  0.101424  0.004799  0.180241  1.004191
# 73   0.000041  0.834456  1.103663  0.101424  0.004799  0.180241  1.004191
# 74   0.000041  0.834456  1.103663  0.101424  0.004799  0.180241  1.004191
# 75   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 76   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 77   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 78   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 79   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 80   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 81   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 82   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 83   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 84   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 85   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 86   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 87   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 88   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 89   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 90   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 91   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 92   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 93   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 94   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 95   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 96   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 97   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 98   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
# 99   0.000040  0.845084  1.028147  0.104566  0.004847  0.194829  1.046425
ax[3,1].plot(x0,theta['tau_u'],color='brown',label='TAU_U')
ax[4,0].plot(x0,theta['ks'],color='red',label='not from contrast')
ax[4,1].plot(x0,theta['kc'],color='blue',label='contrast')


ax[0,0].set_title('BETA')
ax[0,1].set_title('GAMMA')
ax[1,0].set_title('SIGMA (noise)')
ax[1,1].set_title('ALPHA')
ax[2,0].set_title('MU')
ax[2,1].set_title('BASELINE INPUT (KB)')
ax[3,0].set_title('TAU_A')
ax[3,1].set_title('TAU_U')
ax[4,0].set_title('Not Contrast Stimulus')
ax[4,1].set_title('Contrast Stimulus')


fig.get_figure()
fig.set_size_inches(10,10)
fig.tight_layout()
#fig.savefig(savepath+'', dpi=100)

# %%
chicol = ['CHI: First Epoch Probability',
          'CHI: U1 Mean Dominance Time',
          'CHI: U2 Mean Dominance Time',
          'CHI: U1 std for CV=0.6',
          'CHI: U2 std for CV=0.6'
         ]

# %%
best = allchi.idxmin()
best
# Out:
# 75

# %%
dfbest = pd.DataFrame(mcchi[best])
chiallsave = dfbest.T
chiallsave.columns = chicol
#chiallsave.index.name = 1
chiallsave
# Out:
#     CHI: First Epoch Probability  CHI: U1 Mean Dominance Time  \
# 0                       0.361301                     1.777215
# 20                     12.735543                     0.094765
# 40                      6.657609                     0.553069
# 60                      1.010101                     0.976341
# 80                      3.092784                     1.323886
#
#     CHI: U2 Mean Dominance Time  CHI: U1 std for CV=0.6  \
# 0                      0.551359                0.825780
# 20                     0.182397                0.818155
# 40                     0.659483                0.835773
# 60                     0.260991                4.049453
# 80                     0.364095                3.691561
#
#     CHI: U2 std for CV=0.6
# 0                 0.092299
# 20                1.041414
# 40                1.004254
# 60                2.580540
# 80                2.362765

# %%
thetasave = mctheta.iloc[best]
thetasave
# Out:
# alpha       0.000040
# beta        0.845084
# gamma       1.028147
# kb          0.104566
# kc          0.004847
# ks          0.194829
# mu          1.046425
# sigma       0.024701
# tau_a    2700.451575
# tau_u      14.093946
# Name: 75, dtype: float64

# %%
#thetasave.to_pickle(pathname+'altstim.pkl')
#thetasave.to_pickle(modelpath+'altstim.pkl')

# %%
colsum = dfbest.sum(axis=1)
colsum['CHI SUM'] = colsum.sum()
colsum
# Out:
# FIRST_EPOCH_PROB_U1    23.857336
# MEAN_U1                 4.725276
# MEAN_U2                 2.018324
# SD_U1                  10.220724
# SD_U2                   7.081272
# CHI SUM                47.902933
# dtype: float64

# %%
x = np.linspace(0, 2 * np.pi, 400)
z = np.linspace(0, 4 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, ax = plt.subplots(4,2)
#figsize=(10,14)

ax[0,0].plot(z,y)
ax[0,1].plot(x,y)

fig.get_figure()
fig.tight_layout()
fig.set_size_inches(8,8)
