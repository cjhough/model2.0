# %%
# !pwd
# Out:
# /Users/houghtoncj/Documents/GitHub/model2.0/storeresults

# %%
# !ls *.pkl
# Out:
# CHISQpmc1.pkl      THETApmc10.pkl     pm200_150SUM.pkl   pm200_50CHISQ.pkl
# CHISQpmc10.pkl     pm200_100CHISQ.pkl pm200_150THETA.pkl pm200_50SUM.pkl
# SUMpmc1.pkl        pm200_100SUM.pkl   pm200_200CHISQ.pkl pm200_50THETA.pkl
# SUMpmc10.pkl       pm200_100THETA.pkl pm200_200SUM.pkl
# THETApmc1.pkl      pm200_150CHISQ.pkl pm200_200THETA.pkl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pathname = str('/Users/houghtoncj/Documents/GitHub/model2.0/storeresults/')
modelpath = str('/Users/houghtoncj/Documents/GitHub/model2.0/')
#savepath = str('/Users/carly/Desktop/')

# %%
def readchi(name):
    chiread = pd.read_pickle(name+'CHISQ.pkl')
    return chiread
def readtheta(name):
    thetaread = pd.read_pickle(name+'THETA.pkl')
    return thetaread
def readsum(name):
    sumread  = pd.read_pickle(name+'SUM.pkl')
    return sumread

# %%
mc1 = str('pm200_200')

# %%
mc1sum = readsum(mc1)
mc1theta = readtheta(mc1)
mc1chi = readchi(mc1)

# %%
fig, axs = plt.subplots(2)

mc1sum.plot.line(ax = axs[0])

fig.set_size_inches(8,8)
fig.tight_layout()
fig.get_figure()

#fig.savefig(savepath+'',dpi=100)

# %%
mc1sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 200
# Data columns (total 5 columns):
# FIRST_EPOCH_PROB_U1    201 non-null float64
# MEAN_U1                201 non-null float64
# MEAN_U2                201 non-null float64
# SD_U1                  201 non-null float64
# SD_U2                  201 non-null float64
# dtypes: float64(5)
# memory usage: 9.4 KB

# %%
allchi = mc1sum.sum(axis=1)
allchi.idxmin()
# Out:
# 173

# %%
def kc(dic):
    s1 = dic
    for key, value in s1.items():
        # do something with value
        s1[key] = value
    return s1

# %%
#thetakc = pd.DataFrame.from_records(dfc3theta['KC'])

# %%
steps = len(mc1sum)
x0 = np.arange(0,steps)

# %%
theta = mc1theta
theta
# Out:
#      alpha      beta     gamma        kb        kc        ks        mu  \
# 0      0.0  1.361625  2.044118  0.116356  0.002563  0.232233  0.987767
# 1      0.0  1.361625  2.044118  0.116356  0.002563  0.232233  0.987767
# 2      0.0  1.252554  1.914922  0.120195  0.002633  0.225102  0.962994
# 3      0.0  1.277137  2.061278  0.120135  0.002744  0.217163  1.022113
# 4      0.0  1.277137  2.061278  0.120135  0.002744  0.217163  1.022113
# 5      0.0  1.277137  2.061278  0.120135  0.002744  0.217163  1.022113
# 6      0.0  1.277137  2.061278  0.120135  0.002744  0.217163  1.022113
# 7      0.0  1.277137  2.061278  0.120135  0.002744  0.217163  1.022113
# 8      0.0  1.277137  2.061278  0.120135  0.002744  0.217163  1.022113
# 9      0.0  1.280488  2.083952  0.112404  0.002793  0.213175  1.089972
# 10     0.0  1.280488  2.083952  0.112404  0.002793  0.213175  1.089972
# 11     0.0  1.280488  2.083952  0.112404  0.002793  0.213175  1.089972
# 12     0.0  1.280488  2.083952  0.112404  0.002793  0.213175  1.089972
ax[0,2].plot(x0,theta['sigma'],color='purple',label='SIGMA')
ax[1,0].plot(x0,theta['alpha'],color='yellow',label='ALPHA')
ax[1,1].plot(x0,theta['mu'],color='black',label='MU')
ax[1,2].plot(x0,theta['kb'],color='pink',label='BASELINE INPUT (KB)')
ax[2,0].plot(x0,theta['tau_a'],color='orange',label='TAU_A')
ax[2,1].plot(x0,theta['tau_u'],color='brown',label='TAU_U')
ax[3,0].plot(x0,theta['ks'],color='red',label='not from contrast')
ax[3,1].plot(x0,theta['kc'],color='blue',label='contrast')


ax[0,0].set_title('BETA')
ax[0,1].set_title('GAMMA')
ax[0,2].set_title('SIGMA (noise)')
ax[1,0].set_title('ALPHA')
ax[1,1].set_title('MU')
ax[1,2].set_title('BASELINE INPUT (KB)')
ax[2,0].set_title('TAU_A')
ax[2,1].set_title('TAU_U')
ax[3,0].set_title('Not Contrast Stimulus')
ax[3,1].set_title('Contrast Stimulus')

fig.tight_layout()
fig.get_figure()
fig.set_size_inches(10,10)
#fig.savefig(savepath+'', dpi=100)

# %%
chicol = ['CHI: First Epoch Probability',
          'CHI: U1 Mean Dominance Time',
          'CHI: U2 Mean Dominance Time',
          'CHI: U1 std for CV=0.6',
          'CHI: U2 std for CV=0.6'
         ]

# %%
best = allchi.idxmin()

# %%
dfbest = pd.DataFrame(mc1chi[best])
chiallsave = dfbest.T
chiallsave.columns = chicol
#chiallsave.index.name = 1
chiallsave
# Out:
#     CHI: First Epoch Probability  CHI: U1 Mean Dominance Time  \
# 0                       0.160256                     5.777985
# 20                     15.430983                     5.667251
# 40                     27.329193                     5.985020
# 60                     20.481928                     7.574764
# 80                      8.695652                     7.945700
#
#     CHI: U2 Mean Dominance Time  CHI: U1 std for CV=0.6  \
# 0                      5.484210                5.133052
# 20                     5.392279                5.539566
# 40                     5.281671                6.554230
# 60                     6.010766                7.360499
# 80                     5.700193                8.545465
#
#     CHI: U2 std for CV=0.6
# 0                 4.813671
# 20                5.301841
# 40                5.895462
# 60                5.809952
# 80                6.460835

# %%
thetasave = mc1theta.iloc[best]
thetasave
# Out:
# alpha       0.000000
# beta        1.127209
# gamma       1.777396
# kb          0.100947
# kc          0.002921
# ks          0.228017
# mu          1.122287
# sigma       0.045653
# tau_a    1500.853819
# tau_u       8.940977
# Name: 173, dtype: float64

# %%
thetasave['alpha']=0.0001

# %%
#thetasave.to_pickle(pathname+'IP2.pkl')
#thetasave.to_pickle(modelpath+'IP2.pkl')

# %%
colsum = dfbest.sum(axis=1)
colsum['CHI SUM'] = colsum.sum()
colsum
# Out:
# FIRST_EPOCH_PROB_U1     72.098011
# MEAN_U1                 32.950720
# MEAN_U2                 27.869119
# SD_U1                   33.132811
# SD_U2                   28.281761
# CHI SUM                194.332424
# dtype: float64

# %%
x = np.linspace(0, 2 * np.pi, 400)
z = np.linspace(0, 4 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, ax = plt.subplots(4,2)
#figsize=(10,14)

ax[0,0].plot(z,y)
ax[0,1].plot(x,y)

fig.get_figure()
fig.tight_layout()
fig.set_size_inches(8,8)
