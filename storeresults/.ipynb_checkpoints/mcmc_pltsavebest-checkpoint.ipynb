# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pwd
# Out:
# /Users/carly/CODE/model2.0/storeresults

# %%
pathname = str('/Users/carly/CODE/model2.0/initials/')
modelpath = str('/Users/carly/CODE/model2.0/')
#savepath = str('/Users/carly/Desktop/')

# %%
def readchi(name):
    chiread = pd.read_pickle(name+'CHISQ.pkl')
    return chiread
def readtheta(name):
    thetaread = pd.read_pickle(name+'THETA.pkl')
    return thetaread
def readsum(name):
    sumread  = pd.read_pickle(name+'SUM.pkl')
    return sumread

# %%
# !ls *.pkl
# Out:
# IP2_200_200CHISQ.pkl           beethoven5_120CHISQ.pkl
# IP2_200_200SUM.pkl             beethoven5_120SUM.pkl
# IP2_200_200THETA.pkl           beethoven5_120THETA.pkl
# artifice1_200_200CHISQ.pkl     beethoven5_140CHISQ.pkl
# artifice1_200_200SUM.pkl       beethoven5_140SUM.pkl
# artifice1_200_200THETA.pkl     beethoven5_140THETA.pkl
# artifice1branch100100CHISQ.pkl beethoven5_160CHISQ.pkl
# artifice1branch100100SUM.pkl   beethoven5_160SUM.pkl
# artifice1branch100100THETA.pkl beethoven5_160THETA.pkl
# artifice1branch2_100CHISQ.pkl  beethoven5_180CHISQ.pkl
# artifice1branch2_100SUM.pkl    beethoven5_180SUM.pkl
# artifice1branch2_100THETA.pkl  beethoven5_180THETA.pkl
# artifice2_200_200CHISQ.pkl     beethoven5_200CHISQ.pkl
# artifice2_200_200SUM.pkl       beethoven5_200SUM.pkl
# artifice2_200_200THETA.pkl     beethoven5_200THETA.pkl
# artifice_3_200_200CHISQ.pkl    beethoven5_20CHISQ.pkl
# artifice_3_200_200SUM.pkl      beethoven5_20SUM.pkl
# artifice_3_200_200THETA.pkl    beethoven5_20THETA.pkl
# bach140_100CHISQ.pkl           beethoven5_40CHISQ.pkl
# bach140_100SUM.pkl             beethoven5_40SUM.pkl
# bach140_100THETA.pkl           beethoven5_40THETA.pkl
# bach140_20CHISQ.pkl            beethoven5_60CHISQ.pkl
# bach140_20SUM.pkl              beethoven5_60SUM.pkl
# bach140_20THETA.pkl            beethoven5_60THETA.pkl
# bach140_40CHISQ.pkl            beethoven5_80CHISQ.pkl
# bach140_40SUM.pkl              beethoven5_80SUM.pkl
# bach140_40THETA.pkl            beethoven5_80THETA.pkl
# bach140_60CHISQ.pkl            beethoven9_100CHISQ.pkl
# bach140_60SUM.pkl              beethoven9_100SUM.pkl
# bach140_60THETA.pkl            beethoven9_100THETA.pkl
# bach140_80CHISQ.pkl            beethoven9_120CHISQ.pkl
# bach140_80SUM.pkl              beethoven9_120SUM.pkl
# bach140_80THETA.pkl            beethoven9_120THETA.pkl
# bach_100CHISQ.pkl              beethoven9_140CHISQ.pkl
# bach_100SUM.pkl                beethoven9_140SUM.pkl
# bach_100THETA.pkl              beethoven9_140THETA.pkl
# bach_120CHISQ.pkl              beethoven9_160CHISQ.pkl
# bach_120SUM.pkl                beethoven9_160SUM.pkl
# bach_120THETA.pkl              beethoven9_160THETA.pkl
# bach_140CHISQ.pkl              beethoven9_180CHISQ.pkl
# bach_140SUM.pkl                beethoven9_180SUM.pkl
# bach_140THETA.pkl              beethoven9_180THETA.pkl
# bach_160CHISQ.pkl              beethoven9_200CHISQ.pkl
# bach_160SUM.pkl                beethoven9_200SUM.pkl
# bach_160THETA.pkl              beethoven9_200THETA.pkl
# bach_180CHISQ.pkl              beethoven9_20CHISQ.pkl
# bach_180SUM.pkl                beethoven9_20SUM.pkl
# bach_180THETA.pkl              beethoven9_20THETA.pkl
# bach_200CHISQ.pkl              beethoven9_40CHISQ.pkl
# bach_200SUM.pkl                beethoven9_40SUM.pkl
# bach_200THETA.pkl              beethoven9_40THETA.pkl
# bach_20CHISQ.pkl               beethoven9_60CHISQ.pkl
# bach_20SUM.pkl                 beethoven9_60SUM.pkl
# bach_20THETA.pkl               beethoven9_60THETA.pkl
# bach_40CHISQ.pkl               beethoven9_80CHISQ.pkl
# bach_40SUM.pkl                 beethoven9_80SUM.pkl
# bach_40THETA.pkl               beethoven9_80THETA.pkl
# bach_60CHISQ.pkl               bizet_100CHISQ.pkl
# bach_60SUM.pkl                 bizet_100SUM.pkl
# bach_60THETA.pkl               bizet_100THETA.pkl
# bach_80CHISQ.pkl               bizet_120CHISQ.pkl
# bach_80SUM.pkl                 bizet_120SUM.pkl
# bach_80THETA.pkl               bizet_120THETA.pkl
# barber_100CHISQ.pkl            bizet_140CHISQ.pkl
# barber_100SUM.pkl              bizet_140SUM.pkl
# barber_100THETA.pkl            bizet_140THETA.pkl
# barber_120CHISQ.pkl            bizet_160CHISQ.pkl
# barber_120SUM.pkl              bizet_160SUM.pkl
# barber_120THETA.pkl            bizet_160THETA.pkl
# barber_140CHISQ.pkl            bizet_180CHISQ.pkl
# barber_140SUM.pkl              bizet_180SUM.pkl
# barber_140THETA.pkl            bizet_180THETA.pkl
# barber_160CHISQ.pkl            bizet_200CHISQ.pkl
# barber_160SUM.pkl              bizet_200SUM.pkl
# barber_160THETA.pkl            bizet_200THETA.pkl
# barber_180CHISQ.pkl            bizet_20CHISQ.pkl
# barber_180SUM.pkl              bizet_20SUM.pkl
# barber_180THETA.pkl            bizet_20THETA.pkl
# barber_200CHISQ.pkl            bizet_40CHISQ.pkl
# barber_200SUM.pkl              bizet_40SUM.pkl
# barber_200THETA.pkl            bizet_40THETA.pkl
# barber_20CHISQ.pkl             bizet_60CHISQ.pkl
# barber_20SUM.pkl               bizet_60SUM.pkl
# barber_20THETA.pkl             bizet_60THETA.pkl
# barber_40CHISQ.pkl             bizet_80CHISQ.pkl
# barber_40SUM.pkl               bizet_80SUM.pkl
# barber_40THETA.pkl             bizet_80THETA.pkl
# barber_60CHISQ.pkl             brahms_100CHISQ.pkl
# barber_60SUM.pkl               brahms_100SUM.pkl
# barber_60THETA.pkl             brahms_100THETA.pkl
# barber_80CHISQ.pkl             brahms_120CHISQ.pkl
# barber_80SUM.pkl               brahms_120SUM.pkl
# barber_80THETA.pkl             brahms_120THETA.pkl
# beethoven1_100CHISQ.pkl        brahms_140CHISQ.pkl
# beethoven1_100SUM.pkl          brahms_140SUM.pkl
# beethoven1_100THETA.pkl        brahms_140THETA.pkl
# beethoven2_100CHISQ.pkl        brahms_160CHISQ.pkl
# beethoven2_100SUM.pkl          brahms_160SUM.pkl
# beethoven2_100THETA.pkl        brahms_160THETA.pkl
# beethoven2_120CHISQ.pkl        brahms_180CHISQ.pkl
# beethoven2_120SUM.pkl          brahms_180SUM.pkl
# beethoven2_120THETA.pkl        brahms_180THETA.pkl
# beethoven2_140CHISQ.pkl        brahms_200CHISQ.pkl
# beethoven2_140SUM.pkl          brahms_200SUM.pkl
# beethoven2_140THETA.pkl        brahms_200THETA.pkl
# beethoven2_160CHISQ.pkl        brahms_20CHISQ.pkl
# beethoven2_160SUM.pkl          brahms_20SUM.pkl
# beethoven2_160THETA.pkl        brahms_20THETA.pkl
# beethoven2_180CHISQ.pkl        brahms_40CHISQ.pkl
# beethoven2_180SUM.pkl          brahms_40SUM.pkl
# beethoven2_180THETA.pkl        brahms_40THETA.pkl
# beethoven2_200CHISQ.pkl        brahms_60CHISQ.pkl
# beethoven2_200SUM.pkl          brahms_60SUM.pkl
# beethoven2_200THETA.pkl        brahms_60THETA.pkl
# beethoven2_20CHISQ.pkl         brahms_80CHISQ.pkl
# beethoven2_20SUM.pkl           brahms_80SUM.pkl
# beethoven2_20THETA.pkl         brahms_80THETA.pkl
# beethoven2_40CHISQ.pkl         bruch_100CHISQ.pkl
# beethoven2_40SUM.pkl           bruch_100SUM.pkl
# beethoven2_40THETA.pkl         bruch_100THETA.pkl
# beethoven2_60CHISQ.pkl         bruch_120CHISQ.pkl
# beethoven2_60SUM.pkl           bruch_120SUM.pkl
# beethoven2_60THETA.pkl         bruch_120THETA.pkl
# beethoven2_80CHISQ.pkl         bruch_140CHISQ.pkl
# beethoven2_80SUM.pkl           bruch_140SUM.pkl
# beethoven2_80THETA.pkl         bruch_140THETA.pkl
# beethoven3100CHISQ.pkl         bruch_160CHISQ.pkl
# beethoven3100SUM.pkl           bruch_160SUM.pkl
# beethoven3100THETA.pkl         bruch_160THETA.pkl
# beethoven3120CHISQ.pkl         bruch_180CHISQ.pkl
# beethoven3120SUM.pkl           bruch_180SUM.pkl
# beethoven3120THETA.pkl         bruch_180THETA.pkl
# beethoven3140CHISQ.pkl         bruch_200CHISQ.pkl
# beethoven3140SUM.pkl           bruch_200SUM.pkl
# beethoven3140THETA.pkl         bruch_200THETA.pkl
# beethoven3160CHISQ.pkl         bruch_20CHISQ.pkl
# beethoven3160SUM.pkl           bruch_20SUM.pkl
# beethoven3160THETA.pkl         bruch_20THETA.pkl
# beethoven3180CHISQ.pkl         bruch_40CHISQ.pkl
# beethoven3180SUM.pkl           bruch_40SUM.pkl
# beethoven3180THETA.pkl         bruch_40THETA.pkl
# beethoven3200CHISQ.pkl         bruch_60CHISQ.pkl
# beethoven3200SUM.pkl           bruch_60SUM.pkl
# beethoven3200THETA.pkl         bruch_60THETA.pkl
# beethoven320CHISQ.pkl          bruch_80CHISQ.pkl
# beethoven320SUM.pkl            bruch_80SUM.pkl
# beethoven320THETA.pkl          bruch_80THETA.pkl
# beethoven340CHISQ.pkl          cepbach_100CHISQ.pkl
# beethoven340SUM.pkl            cepbach_100SUM.pkl
# beethoven340THETA.pkl          cepbach_100THETA.pkl
# beethoven360CHISQ.pkl          cepbach_150CHISQ.pkl
# beethoven360SUM.pkl            cepbach_150SUM.pkl
# beethoven360THETA.pkl          cepbach_150THETA.pkl
# beethoven380CHISQ.pkl          cepbach_200CHISQ.pkl
# beethoven380SUM.pkl            cepbach_200SUM.pkl
# beethoven380THETA.pkl          cepbach_200THETA.pkl
# beethoven4_100CHISQ.pkl        cepbach_50CHISQ.pkl
# beethoven4_100SUM.pkl          cepbach_50SUM.pkl
# beethoven4_100THETA.pkl        cepbach_50THETA.pkl
# beethoven4_120CHISQ.pkl        chopin_100CHISQ.pkl
# beethoven4_120SUM.pkl          chopin_100SUM.pkl
# beethoven4_120THETA.pkl        chopin_100THETA.pkl
# beethoven4_140CHISQ.pkl        chopin_20CHISQ.pkl
# beethoven4_140SUM.pkl          chopin_20SUM.pkl
# beethoven4_140THETA.pkl        chopin_20THETA.pkl
# beethoven4_160CHISQ.pkl        chopin_40CHISQ.pkl
# beethoven4_160SUM.pkl          chopin_40SUM.pkl
# beethoven4_160THETA.pkl        chopin_40THETA.pkl
# beethoven4_180CHISQ.pkl        chopin_60CHISQ.pkl
# beethoven4_180SUM.pkl          chopin_60SUM.pkl
# beethoven4_180THETA.pkl        chopin_60THETA.pkl
# beethoven4_200CHISQ.pkl        chopin_80CHISQ.pkl
# beethoven4_200SUM.pkl          chopin_80SUM.pkl
# beethoven4_200THETA.pkl        chopin_80THETA.pkl
# beethoven4_20CHISQ.pkl         couperin_100CHISQ.pkl
# beethoven4_20SUM.pkl           couperin_100SUM.pkl
# beethoven4_20THETA.pkl         couperin_100THETA.pkl
# beethoven4_40CHISQ.pkl         couperin_20CHISQ.pkl
# beethoven4_40SUM.pkl           couperin_20SUM.pkl
# beethoven4_40THETA.pkl         couperin_20THETA.pkl
# beethoven4_60CHISQ.pkl         couperin_40CHISQ.pkl
# beethoven4_60SUM.pkl           couperin_40SUM.pkl
# beethoven4_60THETA.pkl         couperin_40THETA.pkl
# beethoven4_80CHISQ.pkl         couperin_60CHISQ.pkl
# beethoven4_80SUM.pkl           couperin_60SUM.pkl
# beethoven4_80THETA.pkl         couperin_60THETA.pkl
# beethoven5_100CHISQ.pkl        couperin_80CHISQ.pkl
# beethoven5_100SUM.pkl          couperin_80SUM.pkl
# beethoven5_100THETA.pkl        couperin_80THETA.pkl

# %%
p1 = str('cepbach_200')

# %%
#bach/cepbach
#barber/copland
#beethoven3/beethoven6
#beethoven4/beethoven8
#beethoven5/beethoven7
#bizet/strauss
#brahms/faure
#bruch
#beethoven2/chopin/
#beethoven9/couperin

# %%
mcsum = readsum(p1)
mctheta = readtheta(p1)
mcchi = readchi(p1)

# %%
fig = plt.Figure()

mcsum.plot.line(title='bruch')

fig.set_size_inches(10,8)
#fig.tight_layout()
fig.get_figure()

#fig.savefig('/Users/carly/Desktop/artifice1_MCMC')

# %%
mcsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 
ax[1,1].plot(x0,theta['alpha'],color='yellow',label='ALPHA')
ax[2,0].plot(x0,theta['mu'],color='black',label='MU')
ax[2,1].plot(x0,theta['kb'],color='pink',label='BASELINE INPUT (KB)')
ax[3,0].plot(x0,theta['tau_a'],color='orange',label='TAU_A')
ax[3,1].plot(x0,theta['tau_u'],color='brown',label='TAU_U')
ax[4,0].plot(x0,theta['ks'],color='red',label='not from contrast')
ax[4,1].plot(x0,theta['kc'],color='blue',label='contrast')


ax[0,0].set_title('BETA')
ax[0,1].set_title('GAMMA')
ax[1,0].set_title('SIGMA (noise)')
ax[1,1].set_title('ALPHA')
ax[2,0].set_title('MU')
ax[2,1].set_title('BASELINE INPUT (KB)')
ax[3,0].set_title('TAU_A')
ax[3,1].set_title('TAU_U')
ax[4,0].set_title('Not Contrast Stimulus')
ax[4,1].set_title('Contrast Stimulus')


fig.get_figure()
fig.set_size_inches(10,10)
fig.tight_layout()
#fig.savefig(savepath+'', dpi=100)

# %%
chicol = ['CHI: First Epoch Probability',
          'CHI: U1 Mean Dominance Time',
          'CHI: U2 Mean Dominance Time',
          'CHI: U1 std for CV=0.6',
          'CHI: U2 std for CV=0.6'
         ]

# %%
best = allchi.idxmin()
best
# Out:
# 95

# %%
dfbest = pd.DataFrame(mcchi[best])
chiallsave = dfbest.T
chiallsave.columns = chicol
#chiallsave.index.name = 1
chiallsave
# Out:
#     CHI: First Epoch Probability  CHI: U1 Mean Dominance Time  \
# 0                       0.361301                     0.249481
# 20                      0.614439                     0.002825
# 40                      0.000000                     0.008523
# 60                      0.000000                     0.088388
# 80                      0.000000                     0.087264
#
#     CHI: U2 Mean Dominance Time  CHI: U1 std for CV=0.6  \
# 0                      0.057210                1.003019
# 20                     0.406187                0.635092
# 40                     1.209795                0.363051
# 60                     2.357566                0.306549
# 80                     3.490741                0.132957
#
#     CHI: U2 std for CV=0.6
# 0                 0.613764
# 20                1.707031
# 40                2.395685
# 60                3.088794
# 80                3.671111

# %%
thetasave = mctheta.iloc[best]
thetasave
# Out:
# alpha       0.000053
# beta        0.820445
# gamma       1.002089
# kb          0.123951
# kc          0.004703
# ks          0.172214
# mu          0.787044
# sigma       0.022573
# tau_a    2672.963764
# tau_u      14.947085
# Name: 95, dtype: float64

# %%
#thetasave.to_pickle(pathname+'cepbach95.pkl')
#thetasave.to_pickle(modelpath+'cepbach95.pkl')

# %%
colsum = dfbest.sum(axis=1)
colsum['CHI SUM'] = colsum.sum()
colsum
# Out:
# FIRST_EPOCH_PROB_U1     0.975740
# MEAN_U1                 0.436481
# MEAN_U2                 7.521499
# SD_U1                   2.440669
# SD_U2                  11.476386
# CHI SUM                22.850775
# dtype: float64

# %%
x = np.linspace(0, 2 * np.pi, 400)
z = np.linspace(0, 4 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, ax = plt.subplots(4,2)
#figsize=(10,14)

ax[0,0].plot(z,y)
ax[0,1].plot(x,y)

fig.get_figure()
fig.tight_layout()
fig.set_size_inches(8,8)
