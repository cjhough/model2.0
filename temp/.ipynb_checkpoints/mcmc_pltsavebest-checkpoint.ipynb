# %%
# !pwd
# Out:
# /Users/houghtoncj/Documents/GitHub/model2.0/storeresults

# %%
# !ls *.pkl
# Out:
# CHISQpmc1.pkl               artifice_3_200_150CHISQ.pkl
# CHISQpmc10.pkl              artifice_3_200_150SUM.pkl
# IP2_200_100CHISQ.pkl        artifice_3_200_150THETA.pkl
# IP2_200_100SUM.pkl          artifice_3_200_200CHISQ.pkl
# IP2_200_100THETA.pkl        artifice_3_200_200SUM.pkl
# IP2_200_150CHISQ.pkl        artifice_3_200_200THETA.pkl
# IP2_200_150SUM.pkl          artifice_3_200_50CHISQ.pkl
# IP2_200_150THETA.pkl        artifice_3_200_50SUM.pkl
# IP2_200_200CHISQ.pkl        artifice_3_200_50THETA.pkl
# IP2_200_200SUM.pkl          pm200_100CHISQ.pkl
# IP2_200_200THETA.pkl        pm200_100SUM.pkl
# IP2_200_50CHISQ.pkl         pm200_100THETA.pkl
# IP2_200_50SUM.pkl           pm200_150CHISQ.pkl
# IP2_200_50THETA.pkl         pm200_150SUM.pkl
# SUMpmc1.pkl                 pm200_150THETA.pkl
# SUMpmc10.pkl                pm200_200CHISQ.pkl
# THETApmc1.pkl               pm200_200SUM.pkl
# THETApmc10.pkl              pm200_200THETA.pkl
# artifice_3_200_100CHISQ.pkl pm200_50CHISQ.pkl
# artifice_3_200_100SUM.pkl   pm200_50SUM.pkl
# artifice_3_200_100THETA.pkl pm200_50THETA.pkl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pathname = str('/Users/houghtoncj/Documents/GitHub/model2.0/storeresults/')
modelpath = str('/Users/houghtoncj/Documents/GitHub/model2.0/')
#savepath = str('/Users/carly/Desktop/')

# %%
def readchi(name):
    chiread = pd.read_pickle(name+'CHISQ.pkl')
    return chiread
def readtheta(name):
    thetaread = pd.read_pickle(name+'THETA.pkl')
    return thetaread
def readsum(name):
    sumread  = pd.read_pickle(name+'SUM.pkl')
    return sumread

# %%
mc1 = str('artifice_3_200_200')

# %%
mc1sum = readsum(mc1)
mc1theta = readtheta(mc1)
mc1chi = readchi(mc1)

# %%
fig, axs = plt.subplots(2)

mc1sum.plot.line(ax = axs[0])

fig.set_size_inches(8,8)
fig.tight_layout()
fig.get_figure()

#fig.savefig(savepath+'',dpi=100)

# %%
mc1sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 200
# Data columns (total 5 columns):
# FIRST_EPOCH_PROB_U1    201 non-null float64
# MEAN_U1                201 non-null float64
# MEAN_U2                201 non-null float64
# SD_U1                  201 non-null float64
# SD_U2                  201 non-null float64
# dtypes: float64(5)
# memory usage: 9.4 KB

# %%
allchi = mc1sum.sum(axis=1)
allchi.idxmin()
# Out:
# 184

# %%
def kc(dic):
    s1 = dic
    for key, value in s1.items():
        # do something with value
        s1[key] = value
    return s1

# %%
#thetakc = pd.DataFrame.from_records(dfc3theta['KC'])

# %%
steps = len(mc1sum)
x0 = np.arange(0,steps)

# %%
theta = mc1theta
theta
# Out:
#         alpha      beta     gamma        kb        kc        ks        mu  \
# 0    0.000080  1.121462  1.670622  0.124143  0.002489  0.195865  1.273642
#
ax[1,2].plot(x0,theta['kb'],color='pink',label='BASELINE INPUT (KB)')
ax[2,0].plot(x0,theta['tau_a'],color='orange',label='TAU_A')
ax[2,1].plot(x0,theta['tau_u'],color='brown',label='TAU_U')
ax[3,0].plot(x0,theta['ks'],color='red',label='not from contrast')
ax[3,1].plot(x0,theta['kc'],color='blue',label='contrast')


ax[0,0].set_title('BETA')
ax[0,1].set_title('GAMMA')
ax[0,2].set_title('SIGMA (noise)')
ax[1,0].set_title('ALPHA')
ax[1,1].set_title('MU')
ax[1,2].set_title('BASELINE INPUT (KB)')
ax[2,0].set_title('TAU_A')
ax[2,1].set_title('TAU_U')
ax[3,0].set_title('Not Contrast Stimulus')
ax[3,1].set_title('Contrast Stimulus')

fig.tight_layout()
fig.get_figure()
fig.set_size_inches(10,10)
#fig.savefig(savepath+'', dpi=100)

# %%
chicol = ['CHI: First Epoch Probability',
          'CHI: U1 Mean Dominance Time',
          'CHI: U2 Mean Dominance Time',
          'CHI: U1 std for CV=0.6',
          'CHI: U2 std for CV=0.6'
         ]

# %%
best = allchi.idxmin()

# %%
dfbest = pd.DataFrame(mc1chi[best])
chiallsave = dfbest.T
chiallsave.columns = chicol
#chiallsave.index.name = 1
chiallsave
# Out:
#     CHI: First Epoch Probability  CHI: U1 Mean Dominance Time  \
# 0                       0.080032                     1.006932
# 20                     49.112126                     1.571546
# 40                     15.628816                     1.493657
# 60                      8.333333                     2.929026
# 80                      5.128205                     3.119689
#
#     CHI: U2 Mean Dominance Time  CHI: U1 std for CV=0.6  \
# 0                      0.612184                2.611088
# 20                     1.779426                1.565372
# 40                     1.897244                2.609164
# 60                     2.728570                3.892384
# 80                     2.890452                4.847989
#
#     CHI: U2 std for CV=0.6
# 0                 2.083160
# 20                1.909387
# 40                3.128521
# 60                3.831952
# 80                4.926057

# %%
thetasave = mc1theta.iloc[best]
thetasave
# Out:
# alpha       0.000067
# beta        0.943724
# gamma       1.347079
# kb          0.109861
# kc          0.003166
# ks          0.178345
# mu          1.067869
# sigma       0.031642
# tau_a    2060.690485
# tau_u       9.540702
# Name: 184, dtype: float64

# %%
#thetasave['alpha']=0.0001

# %%
#thetasave.to_pickle(pathname+'IP2.pkl')
#thetasave.to_pickle(modelpath+'beethoven.pkl')

# %%
colsum = dfbest.sum(axis=1)
colsum['CHI SUM'] = colsum.sum()
colsum
# Out:
# FIRST_EPOCH_PROB_U1     78.282512
# MEAN_U1                 10.120850
# MEAN_U2                  9.907875
# SD_U1                   15.525997
# SD_U2                   15.879077
# CHI SUM                129.716311
# dtype: float64

# %%
x = np.linspace(0, 2 * np.pi, 400)
z = np.linspace(0, 4 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, ax = plt.subplots(4,2)
#figsize=(10,14)

ax[0,0].plot(z,y)
ax[0,1].plot(x,y)

fig.get_figure()
fig.tight_layout()
fig.set_size_inches(8,8)
